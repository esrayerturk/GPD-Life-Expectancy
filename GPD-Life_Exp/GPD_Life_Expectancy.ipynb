# %%
# %pip install pandas

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

# %%
gpd_life_exp = pd.read_csv("gpd_life_expectancy.csv")
gpd_life_exp
# Out:
#     Life_Expectancy     GPD
# 0             85.63   48000
# 1             84.85   34000
# 2             84.43   32000
# 3             84.19   18000
# 4             84.09   93000
# 5             84.07   67000
# 6             83.87   34000
# 7             83.86   78000
# 8             83.80   29000
# 9             83.47   33000
# 10            83.46  106000
# 11            83.46   41000
# 12            83.42   56000
# 13            83.07   53000
# 14            83.01   75000
# 15            82.73   58000
# 16            82.72   55000
# 17            82.58  105000
# 18            82.55   24000
# 19            82.52   87000
# 20            82.36  125000
# 21            82.30   57000
# 22            82.27   49000
# 23            82.25   47000
# 24            82.12   52000
# 25            82.09   68000
# 26            82.08   50000
# 27            82.03   20000
# 28            81.90   34000
# 29            81.82   32000
# 30            81.78   28000
# 31            81.54   48000
# ...

# %%
# %pip install matplotlip

# %%
import matplotlib.pyplot as plt

plt.scatter(gpd_life_exp["GPD"], gpd_life_exp["Life_Expectancy"], color="yellow")
plt.xlabel("Life_Expectancy")
plt.ylabel("GPD")
plt.title("GPD-Life_Exp")
plt.show()

# %%
a = 4.38157056
b = 79.65176229652826

def life_exp_tahmini(yıl):
    return a * yıl + b

# %%
yetmisdokuz_yıl_icin_gpd = life_exp_tahmini(79)
print(yetmisdokuz_yıl_icin_gpd)
# Out:
# 425.79583653652827

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(gpd_life_exp[["GPD"]], gpd_life_exp["Life_Expectancy"])
# Out:
# LinearRegression()

# %%
tahmin_edilen_degerler = model.predict(gpd_life_exp[["GPD"]])
tahmin_edilen_degerler
# Out:
# array([81.75491616, 81.14149629, 81.05386488, 80.440445  , 83.72662292,
#        82.58741457, 81.14149629, 83.06938733, 80.92241776, 81.09768058,
#        84.29622709, 81.44820623, 82.10544181, 81.97399469, 82.93794022,
#        82.19307322, 82.0616261 , 84.25241138, 80.70333923, 83.46372868,
#        85.12872549, 82.14925751, 81.79873187, 81.71110046, 81.93017899,
#        82.63123028, 81.84254758, 80.52807641, 81.14149629, 81.05386488,
#        80.87860205, 81.75491616, 81.62346905, 80.96623346, 80.30899788,
#        80.13373506, 80.22136647, 81.44820623, 80.74715494, 80.39662929,
#        79.91465653, 82.98175592, 80.87860205, 80.96623346, 81.09768058,
#        80.39662929, 80.39662929, 80.52807641, 80.52807641, 80.13373506,
#        79.95847224, 80.17755076, 79.82702512, 79.91465653, 79.91465653,
#        79.91465653, 79.91465653])

# %%
model.coef_, model.intercept_
# Out:
# (array([4.38157056e-05]), 79.65176229652826)

# %%
model.predict([[yetmisdokuz_yıl_icin_gpd]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([79.67041884])

# %%
plt.scatter(gpd_life_exp["GPD"], gpd_life_exp["Life_Expectancy"], color="yellow")
plt.plot(gpd_life_exp["GPD"], tahmin_edilen_degerler, color="red")
plt.xlabel("Life_Expectancy")
plt.ylabel("GPD")
plt.title("GPD-Life_Exp")
plt.show()

# %%
plt.scatter(gpd_life_exp["Life_Expectancy"], gpd_life_exp["GPD"], c=gpd_life_exp['küme'])
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], c='red')
plt.xlabel("Life_Expectancy")
plt.ylabel("GPD")
plt.title("GPD-Life_Exp")
plt.show()

# %%
gpd_life_exp.to_csv('gpd_life_expectancy.csv', index=False)

# %%
# cluster number 1 is kısa ömürlü
# cluster number 2 is orta
# cluster number 3 is uzun ömürlü

gpd_life_exp['Yaşam Uzunluğu'] = gpd_life_exp['küme'].replace({0: 'çok kısa ömürlü', 1: 'kısa ömürlü', 2: 'orta', 3: 'uzun ömürlü'})
gpd_life_exp
# Out:
#     Life_Expectancy     GPD  küme   Yaşam Uzunluğu
# 0             85.63   48000     0  çok kısa ömürlü
# 1             84.85   34000     1      kısa ömürlü
# 2             84.43   32000     1      kısa ömürlü
# 3             84.19   18000     1      kısa ömürlü
# 4             84.09   93000     2             orta
# 5             84.07   67000     0  çok kısa ömürlü
# 6             83.87   34000     1      kısa ömürlü
# 7             83.86   78000     0  çok kısa ömürlü
# 8             83.80   29000     1      kısa ömürlü
# 9             83.47   33000     1      kısa ömürlü
# 10            83.46  106000     2             orta
# 11            83.46   41000     0  çok kısa ömürlü
# 12            83.42   56000     0  çok kısa ömürlü
# 13            83.07   53000     0  çok kısa ömürlü
# 14            83.01   75000     0  çok kısa ömürlü
# 15            82.73   58000     0  çok kısa ömürlü
# 16            82.72   55000     0  çok kısa ömürlü
# ...

# %%
gpd_life_exp.to_csv('gpd_life_expectancy_etiketli.csv', index=False)
